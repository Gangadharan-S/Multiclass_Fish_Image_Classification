# %%
# ⚙️ Imports
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications import VGG16, ResNet50, MobileNet, InceptionV3, EfficientNetB0
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report, roc_curve, auc
from sklearn.preprocessing import label_binarize

# 📁 Paths and Constants
Train_Path = "/content/drive/MyDrive/Project/Dataset/images.cv_jzk6llhf18tm3k0kyttxz/data/train"
Val_Path = "/content/drive/MyDrive/Project/Dataset/images.cv_jzk6llhf18tm3k0kyttxz/data/val"
Test_Path = "/content/drive/MyDrive/Project/Dataset/images.cv_jzk6llhf18tm3k0kyttxz/data/test"

IMG_SIZE = (128, 128)
BATCH_SIZE = 16
EPOCHS_CNN = 5
EPOCHS_PRETRAINED = 5
BEST_MODEL_PATH = "/content/drive/MyDrive/Project/Dataset/images.cv_jzk6llhf18tm3k0kyttxz/data/best_fish_model.keras"

# 🧼 Data Preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)

train_gen = train_datagen.flow_from_directory(
    Train_Path, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=True
)
val_gen = ImageDataGenerator(rescale=1./255).flow_from_directory(
    Val_Path, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)
test_gen = ImageDataGenerator(rescale=1./255).flow_from_directory(
    Test_Path, target_size=IMG_SIZE, batch_size=BATCH_SIZE, class_mode='categorical', shuffle=False
)

num_classes = len(train_gen.class_indices)

# 🧠 CNN Model
def create_cnn_model():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3)),
        MaxPooling2D(2, 2),
        Conv2D(64, (3, 3), activation='relu'),
        MaxPooling2D(2, 2),
        Flatten(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(optimizer=Adam(0.001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# 🧠 Pretrained Model Builder with Optional Fine-Tuning
def create_pretrained_model(name, fine_tune_at=None):
    base_models = {
        "VGG16": VGG16,
        "ResNet50": ResNet50,
        "MobileNet": MobileNet,
        "InceptionV3": InceptionV3,
        "EfficientNetB0": EfficientNetB0
    }
    base_model = base_models[name](weights='imagenet', include_top=False, input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3))
    base_model.trainable = False  # freeze all layers initially

    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        Dense(128, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    # Fine-tune last few layers if specified
    if fine_tune_at is not None:
        base_model.trainable = True
        for layer in base_model.layers[:fine_tune_at]:
            layer.trainable = False

    model.compile(optimizer=Adam(0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# 🧪 Training Loop
models = {"CNN": create_cnn_model()}
for name in ["VGG16", "ResNet50", "MobileNet", "InceptionV3", "EfficientNetB0"]:
    # Fine-tune last 20 layers of base model for pretrained
    models[name] = create_pretrained_model(name, fine_tune_at=-20)

best_model = None
best_accuracy = 0
history_dict = {}
metrics_dict = {}

for name, model in models.items():
    print(f"\n🔁 Training {name}...")

    # Callbacks
    checkpoint = ModelCheckpoint(f"{name}_best.keras", save_best_only=True, monitor='val_accuracy', mode='max')
    early_stopping = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)

    # Steps per epoch
    steps_per_epoch = train_gen.samples // BATCH_SIZE
    validation_steps = val_gen.samples // BATCH_SIZE

    # Train
    history = model.fit(
        train_gen,
        steps_per_epoch=steps_per_epoch,
        validation_data=val_gen,
        validation_steps=validation_steps,
        epochs=EPOCHS_CNN if name == 'CNN' else EPOCHS_PRETRAINED,
        callbacks=[checkpoint, early_stopping],
        verbose=1
    )

    history_dict[name] = history.history

    # Evaluate
    val_gen.reset()
    y_true = val_gen.classes
    y_pred = np.argmax(model.predict(val_gen, steps=validation_steps+1), axis=1)

    accuracy = accuracy_score(y_true, y_pred)
    metrics_dict[name] = {
        "Accuracy": accuracy,
        "Precision": precision_score(y_true, y_pred, average='macro', zero_division=1),
        "Recall": recall_score(y_true, y_pred, average='macro', zero_division=1),
        "F1 Score": f1_score(y_true, y_pred, average='macro', zero_division=1),
        "Confusion Matrix": confusion_matrix(y_true, y_pred)
    }

    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_model = model
        best_model_name = name

# Save Best Model and Metrics
if best_model:
    best_model.save(BEST_MODEL_PATH)
    joblib.dump(metrics_dict, "model_metrics.pkl")
    print(f"\n🏆 Best model: {best_model_name} saved at {BEST_MODEL_PATH}")

# 📊 Performance Summary
metrics_df = pd.DataFrame.from_dict(
    {model: {k: v for k, v in metrics_dict[model].items() if k != "Confusion Matrix"} for model in metrics_dict},
    orient='index'
)
print("\n📈 Model Performance:\n", metrics_df)

# 📉 Plot Accuracy & Loss
for name, history in history_dict.items():
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.plot(history['accuracy'], label='Train')
    plt.plot(history['val_accuracy'], label='Val')
    plt.title(f"{name} Accuracy")
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(history['loss'], label='Train')
    plt.plot(history['val_loss'], label='Val')
    plt.title(f"{name} Loss")
    plt.legend()
    plt.tight_layout()
    plt.show()

# 🖼️ Sample Predictions (first batch)
model = load_model(BEST_MODEL_PATH)
class_labels = list(test_gen.class_indices.keys())
test_gen.reset()
test_images, test_labels = next(test_gen)
test_preds = np.argmax(model.predict(test_images), axis=1)

fig, axes = plt.subplots(3, 3, figsize=(10, 10))
fig.suptitle("Sample Predictions", fontsize=16)
for i, ax in enumerate(axes.flat):
    ax.imshow(test_images[i])
    true_label = class_labels[np.argmax(test_labels[i])]
    pred_label = class_labels[test_preds[i]]
    ax.set_title(f"True: {true_label}\nPred: {pred_label}", color='green' if true_label == pred_label else 'red')
    ax.axis("off")
plt.tight_layout()
plt.show()

# 🧾 Classification Report & Confusion Matrix
test_gen.reset()
y_true = test_gen.classes
y_pred_proba = model.predict(test_gen, steps=test_gen.samples // BATCH_SIZE + 1)
y_pred = np.argmax(y_pred_proba, axis=1)

print("\n📋 Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_labels, zero_division=1))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# 🧠 ROC Curve for Multi-Class
y_true_bin = label_binarize(y_true, classes=range(num_classes))
plt.figure(figsize=(10, 8))
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_bin[:, i], y_pred_proba[:, i])
    auc_score = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f"{class_labels[i]} (AUC = {auc_score:.2f})")
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve for Multi-Class Classification")
plt.legend(loc='lower right')
plt.grid()
plt.show()
# Out:
# Found 6285 images belonging to 11 classes.
# Found 1112 images belonging to 11 classes.
# Found 3197 images belonging to 11 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_128_tf_no_top.h5
# 17225924/17225924 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
#
# 🔁 Training CNN...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 2893s 7s/step - accuracy: 0.2989 - loss: 2.0071 - val_accuracy: 0.5571 - val_loss: 1.2861
# Epoch 2/5
#   1/392 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.3125 - loss: 1.5530
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.3125 - loss: 1.5530 - val_accuracy: 0.5498 - val_loss: 1.3038
# Epoch 3/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 52s 133ms/step - accuracy: 0.5172 - loss: 1.3816 - val_accuracy: 0.6123 - val_loss: 1.0612
# Epoch 4/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.6250 - loss: 1.0579 - val_accuracy: 0.6250 - val_loss: 1.0315
# Epoch 5/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 54s 137ms/step - accuracy: 0.6093 - loss: 1.1230 - val_accuracy: 0.7391 - val_loss: 0.7580
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 6s 74ms/step
#
# 🔁 Training VGG16...
# Epoch 1/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 98s 204ms/step - accuracy: 0.4012 - loss: 1.7158 - val_accuracy: 0.8841 - val_loss: 0.4306
# Epoch 2/5
#   1/392 ━━━━━━━━━━━━━━━━━━━━ 40s 103ms/step - accuracy: 0.8125 - loss: 0.4166
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8125 - loss: 0.4166 - val_accuracy: 0.8822 - val_loss: 0.4086
# Epoch 3/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 61s 156ms/step - accuracy: 0.9011 - loss: 0.3542 - val_accuracy: 0.8569 - val_loss: 0.5969
# Epoch 4/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9375 - loss: 0.2584 - val_accuracy: 0.8379 - val_loss: 0.8065
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 8s 94ms/step
#
# 🔁 Training ResNet50...
# Epoch 1/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 85s 175ms/step - accuracy: 0.3136 - loss: 2.0135 - val_accuracy: 0.4230 - val_loss: 1.5837
# Epoch 2/5
#   1/392 ━━━━━━━━━━━━━━━━━━━━ 19s 49ms/step - accuracy: 0.3125 - loss: 1.9226
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.3125 - loss: 1.9226 - val_accuracy: 0.4366 - val_loss: 1.5623
# Epoch 3/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 58s 148ms/step - accuracy: 0.4434 - loss: 1.5641 - val_accuracy: 0.5598 - val_loss: 1.2218
# Epoch 4/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.3125 - loss: 1.9045 - val_accuracy: 0.5688 - val_loss: 1.2206
# Epoch 5/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 80s 204ms/step - accuracy: 0.5048 - loss: 1.4147 - val_accuracy: 0.5598 - val_loss: 1.1751
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 13s 129ms/step
#
# 🔁 Training MobileNet...
# Epoch 1/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 84s 170ms/step - accuracy: 0.5432 - loss: 1.4708 - val_accuracy: 0.9764 - val_loss: 0.1018
# Epoch 2/5
#   1/392 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9375 - loss: 0.2341
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9375 - loss: 0.2341 - val_accuracy: 0.9774 - val_loss: 0.1023
# Epoch 3/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 53s 135ms/step - accuracy: 0.9272 - loss: 0.2418 - val_accuracy: 0.9882 - val_loss: 0.0454
# Epoch 4/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9375 - loss: 0.1662 - val_accuracy: 0.9882 - val_loss: 0.0454
# Epoch 5/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 53s 134ms/step - accuracy: 0.9601 - loss: 0.1214 - val_accuracy: 0.9946 - val_loss: 0.0262
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 15s 177ms/step
#
# 🔁 Training InceptionV3...
# Epoch 1/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 89s 180ms/step - accuracy: 0.4887 - loss: 1.5541 - val_accuracy: 0.8986 - val_loss: 0.3613
# Epoch 2/5
#   1/392 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.6875 - loss: 0.7528
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.6875 - loss: 0.7528 - val_accuracy: 0.9004 - val_loss: 0.3602
# Epoch 3/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 57s 145ms/step - accuracy: 0.8254 - loss: 0.5772 - val_accuracy: 0.9221 - val_loss: 0.2624
# Epoch 4/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.6875 - loss: 0.6120 - val_accuracy: 0.9194 - val_loss: 0.2609
# Epoch 5/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 77s 145ms/step - accuracy: 0.8655 - loss: 0.4331 - val_accuracy: 0.9529 - val_loss: 0.1729
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 18s 165ms/step
#
# 🔁 Training EfficientNetB0...
# Epoch 1/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 107s 197ms/step - accuracy: 0.1280 - loss: 2.3994 - val_accuracy: 0.1694 - val_loss: 2.3263
# Epoch 2/5
#   1/392 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.0625 - loss: 2.3720
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.0625 - loss: 2.3720 - val_accuracy: 0.1694 - val_loss: 2.3268
# Epoch 3/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 53s 135ms/step - accuracy: 0.1429 - loss: 2.3451 - val_accuracy: 0.1694 - val_loss: 2.3044
# Epoch 4/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.2500 - loss: 2.3148 - val_accuracy: 0.1694 - val_loss: 2.3044
# Epoch 5/5
# 392/392 ━━━━━━━━━━━━━━━━━━━━ 53s 136ms/step - accuracy: 0.1663 - loss: 2.3205 - val_accuracy: 0.1694 - val_loss: 2.3028
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 23s 226ms/step
#
# 🏆 Best model: MobileNet saved at /content/drive/MyDrive/Project/Dataset/images.cv_jzk6llhf18tm3k0kyttxz/data/best_fish_model.keras
#
# 📈 Model Performance:
#                  Accuracy  Precision    Recall  F1 Score
# CNN             0.739209   0.776357  0.664183  0.655299
# VGG16           0.882194   0.900650  0.806836  0.801536
# ResNet50        0.562050   0.593130  0.484440  0.467211
# MobileNet       0.994604   0.997174  0.945455  0.959604
# InceptionV3     0.953237   0.957323  0.881666  0.885402
# EfficientNetB0  0.168165   0.924379  0.090909  0.026174
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 200/200 ━━━━━━━━━━━━━━━━━━━━ 1232s 6s/step
#
# 📋 Classification Report:
#
#                                   precision    recall  f1-score   support
#
#                      animal fish       0.98      1.00      0.99       520
#                 animal fish bass       1.00      0.31      0.47        13
#    fish sea_food black_sea_sprat       1.00      1.00      1.00       298
#    fish sea_food gilt_head_bream       1.00      0.99      1.00       315
#    fish sea_food hourse_mackerel       0.99      1.00      1.00       286
#         fish sea_food red_mullet       1.00      0.99      0.99       291
#      fish sea_food red_sea_bream       0.99      1.00      1.00       273
#           fish sea_food sea_bass       1.00      1.00      1.00       327
#             fish sea_food shrimp       1.00      1.00      1.00       289
# fish sea_food striped_red_mullet       0.99      1.00      0.99       293
#              fish sea_food trout       1.00      1.00      1.00       292
#
#                         accuracy                           0.99      3197
#                        macro avg       1.00      0.93      0.95      3197
#                     weighted avg       0.99      0.99      0.99      3197
